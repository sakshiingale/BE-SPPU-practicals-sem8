# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("HousingData.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
# Fill NaN values with the column mean
df['CRIM'].fillna(df['CRIM'].mean(), inplace=True)
df['INDUS'].fillna(df['INDUS'].mean(), inplace=True)
df['ZN'].fillna(df['ZN'].mean(), inplace=True)
df['CHAS'].fillna(df['CHAS'].mean(), inplace=True)
df['AGE'].fillna(df['AGE'].mean(), inplace=True)
df['LSTAT'].fillna(df['LSTAT'].mean(), inplace=True)

# Verify the DataFrame
print(df.isna().sum())


df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_17484\1009835634.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CRIM'].fillna(df['CRIM'].mean(), inplace=True)
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_17484\1009835634.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['INDUS'].fillna(df['INDUS'].mean(), inplace=True)
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_17484\1009835634.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ZN'].fillna(df['ZN'].mean(), inplace=True)
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_17484\1009835634.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CHAS'].fillna(df['CHAS'].mean(), inplace=True)
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_17484\1009835634.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AGE'].fillna(df['AGE'].mean(), inplace=True)
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_17484\1009835634.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LSTAT'].fillna(df['LSTAT'].mean(), inplace=True)
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.size
# Out:
# 7084

# %%
import seaborn as sns 

sns.boxplot(df['MEDV'])
# Out:
# <Axes: ylabel='MEDV'>

# %%
def remove_outliers_iqr(df, target_column):
    Q1 = df[target_column].quantile(0.25)  # 25th percentile
    Q3 = df[target_column].quantile(0.75)  # 75th percentile
    IQR = Q3 - Q1  # Interquartile range

# Define lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

# Remove outliers
    df = df[(df[target_column] >= lower_bound) & (df[target_column] <= upper_bound)]
    return df

# %%
df=remove_outliers_iqr(df, 'MEDV')
sns.boxplot(df['MEDV'])
# Out:
# <Axes: ylabel='MEDV'>

# %%
x=df.iloc[:,0:-1]
y=df['MEDV']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Define Deep Neural Network Model
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)  # Output layer for regression
])

# Compile Model
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.05), loss='mse', metrics=['mae'])

# Train Model
history = model.fit(X_train, y_train, epochs=150, batch_size=16, validation_data=(X_test, y_test), verbose=1)
# Out:
# C:\Users\Sakshi\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 165.3339 - mae: 10.0645 - val_loss: 14.2326 - val_mae: 3.1761
# Epoch 2/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.6569 - mae: 3.0437 - val_loss: 22.6232 - val_mae: 3.6526
# Epoch 3/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.9641 - mae: 3.2173 - val_loss: 16.3533 - val_mae: 3.1937
# Epoch 4/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.4600 - mae: 3.3440 - val_loss: 18.8294 - val_mae: 3.3876
# Epoch 5/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.5432 - mae: 2.8109 - val_loss: 10.7070 - val_mae: 2.5852
# Epoch 6/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8696 - mae: 2.5061 - val_loss: 8.1736 - val_mae: 2.1733
# Epoch 7/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3944 - mae: 2.1083 - val_loss: 8.2434 - val_mae: 2.2685
# Epoch 8/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3966 - mae: 2.4854 - val_loss: 9.8916 - val_mae: 2.4194
# Epoch 9/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.5538 - mae: 2.5792 - val_loss: 18.0920 - val_mae: 3.4617
# Epoch 10/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.0750 - mae: 2.9514 - val_loss: 10.7662 - val_mae: 2.6966
# Epoch 11/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8577 - mae: 2.3551 - val_loss: 9.1476 - val_mae: 2.4135
# Epoch 12/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9890 - mae: 2.3914 - val_loss: 11.2169 - val_mae: 2.6854
# Epoch 13/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0965 - mae: 2.3664 - val_loss: 10.0112 - val_mae: 2.6509
# Epoch 14/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.1485 - mae: 2.8986 - val_loss: 7.1554 - val_mae: 2.0484
# Epoch 15/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0278 - mae: 2.3734 - val_loss: 11.9319 - val_mae: 2.6364
# Epoch 16/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.8654 - mae: 2.7809 - val_loss: 10.6445 - val_mae: 2.6012
# Epoch 17/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.
150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3946 - mae: 1.3770 - val_loss: 5.8785 - val_mae: 1.8377
# Epoch 121/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9236 - mae: 1.3069 - val_loss: 7.4219 - val_mae: 2.0531
# Epoch 122/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1769 - mae: 1.5975 - val_loss: 7.3871 - val_mae: 2.0673
# Epoch 123/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9362 - mae: 1.4760 - val_loss: 8.2414 - val_mae: 2.1780
# Epoch 124/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5441 - mae: 1.4806 - val_loss: 9.0103 - val_mae: 2.2470
# Epoch 125/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0952 - mae: 1.9277 - val_loss: 7.4931 - val_mae: 2.2440
# Epoch 126/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2784 - mae: 1.4065 - val_loss: 7.4165 - val_mae: 2.0963
# Epoch 127/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9377 - mae: 1.5353 - val_loss: 7.3579 - val_mae: 2.1704
# Epoch 128/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8587 - mae: 1.4886 - val_loss: 6.6992 - val_mae: 2.0044
# Epoch 129/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4805 - mae: 1.4413 - val_loss: 8.5225 - val_mae: 2.2865
# Epoch 130/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7921 - mae: 1.2549 - val_loss: 7.7214 - val_mae: 2.1947
# Epoch 131/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6659 - mae: 1.4058 - val_loss: 8.4424 - val_mae: 2.1993
# Epoch 132/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9471 - mae: 1.3496 - val_loss: 8.5715 - val_mae: 2.2341
# Epoch 133/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5971 - mae: 1.4229 - val_loss: 12.4891 - val_mae: 2.8908
# Epoch 134/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8679 - mae: 1.6933 - val_loss: 8.2529 - val_mae: 2.1585
# Epoch 135/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5383 - mae: 1.3689 - val_loss: 6.5800 - val_mae: 1.9987
# Epoch 136/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0946 - mae: 1.3169 - val_loss: 7.9917 - val_mae: 2.1935
# Epoch 137/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0706 - mae: 1.5300 - val_loss: 10.2050 - val_mae: 2.4023
# Epoch 138/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2858 - mae: 1.4155 - val_loss: 11.7167 - val_mae: 2.3824
# Epoch 139/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8796 - mae: 1.6689 - val_loss: 7.1945 - val_mae: 2.0738
# Epoch 140/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7917 - mae: 1.3353 - val_loss: 7.0351 - val_mae: 1.9609
# Epoch 141/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9477 - mae: 1.4824 - val_loss: 9.8382 - val_mae: 2.4491
# Epoch 142/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6766 - mae: 1.7078 - val_loss: 8.2704 - val_mae: 2.1886
# Epoch 143/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8839 - mae: 1.4536 - val_loss: 12.1981 - val_mae: 2.4761
# Epoch 144/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4166 - mae: 1.3684 - val_loss: 7.3072 - val_mae: 2.0064
# Epoch 145/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5102 - mae: 1.4821 - val_loss: 5.8086 - val_mae: 1.8493
# Epoch 146/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6293 - mae: 1.4669 - val_loss: 11.2202 - val_mae: 2.4406
# Epoch 147/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5900 - mae: 1.4754 - val_loss: 8.3296 - val_mae: 2.0512
# Epoch 148/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7578 - mae: 1.2743 - val_loss: 7.2769 - val_mae: 1.9668
# Epoch 149/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2188 - mae: 1.4065 - val_loss: 8.4402 - val_mae: 2.2070
# Epoch 150/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3283 - mae: 1.5327 - val_loss: 8.5366 - val_mae: 2.1559

# %%
#Evaluate Model
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")


# Calculate R-squared (which can be interpreted as a measure of "goodness of fit")
from sklearn.metrics import r2_score
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print(f"R-squared: {r2}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0753 - mae: 2.0329
# Test Loss: 8.53659725189209, Test MAE: 2.155885696411133
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# R-squared: 0.7871993296918629

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.show()
